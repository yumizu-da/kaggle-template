# %%
# %pip install /kaggle/input/*-deps/*.whl \
    --force-reinstall --root-user-action ignore --no-deps --no-index \
    --find-links /kaggle/input/*-deps

# %%
import glob, os
codes_dir = glob.glob("/kaggle/input/*-codes")[0]
os.environ["PYTHONPATH"] = codes_dir
# !python "{codes_dir}/001/run.py"
